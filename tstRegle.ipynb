# %%
import time
from math import pi as pi, sin as sin, tan as tan, cos as cos
from math import radians as radians, degrees as degrees
from Geo import *
from Polygones import *
from Regle import *

# %%
qt = Regle(pi/4,0.23);qt
# Out:
# Regle[(-0.7071067811865475,5.551115123125783e-17), (5.551115123125783e-17,0.7071067811865475), (0.7071067811865475,-5.551115123125783e-17), (-5.551115123125783e-17,-0.7071067811865475)]d = 0.7723691193458118   h = 0.23

# %%
qt.draw()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 qt.draw()
#
# File ~/Python/Formes2D/Regle.py:57, in Regle.draw(self, axes, labels, center, color, save)
#      54 plt.xlim(xmin, xmax)
#      56 plt.axis('off')
# ---> 57 super().draw(color='color')
#      58 title = 'Équilbre stable, densité {:8.6f}, $\\theta$= {:8.6f}°'.format(self.densite,degrees(self.theta))
#      59 if self.P.x < -1e-8:
#
# File ~/Python/Formes2D/Polygones.py:30, in Polygone.draw(self, dx, dy, color)
#      28 plt.plot(xdata, ydata)
#      29 if not color is None:
# ---> 30     plt.fill(xdata, ydata, 'color', alpha=0.30)
#      31 for p in self.sommets:
#      32     p.draw(dx, dy)
#
# File /private/var/tmp/sage-10.5-current/venv/lib/python3.12/site-packages/matplotlib/pyplot.py:3083, in fill(data, *args, **kwargs)
#    3081 @_copy_docstring_and_deprecators(Axes.fill)
#    3082 def fill(*args, data=None, **kwargs) -> list[Polygon]:
# -> 3083     return gca().fill(*args, **({"data": data} if data is not None else {}), **kwargs)
#
# File /private/var/tmp/sage-10.5-current/venv/lib/python3.12/site-packages/matplotlib/axes/_axes.py:5300, in Axes.fill(self, data, *args, **kwargs)
#    5298 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
#    5299 # _get_patches_for_fill returns a generator, convert it to a list.
# -> 5300 patches = [*self._get_patches_for_fill(self, *args, data=data, **kwargs)]
#    5301 for poly in patches:
#    5302     self.add_patch(poly)
#
# File /private/var/tmp/sage-10.5-current/venv/lib/python3.12/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /private/var/tmp/sage-10.5-current/venv/lib/python3.12/site-packages/matplotlib/axes/_base.py:449, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     446 if len(tup) > 1 and isinstance(tup[-1], str):
#     447     # xy is tup with fmt stripped (could still be (y,) only)
#     448     *xy, fmt = tup
# --> 449     linestyle, marker, color = _process_plot_format(
#     450         fmt, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     451 elif len(tup) == 3:
#     452     raise ValueError('third arg must be a format string')
#
# File /private/var/tmp/sage-10.5-current/venv/lib/python3.12/site-packages/matplotlib/axes/_base.py:197, in _process_plot_format(fmt, ambiguous_fmt_datakey)
#     195         i += 2
#     196     else:
# --> 197         raise ValueError(
#     198             errfmt.format(fmt, f"unrecognized character {c!r}"))
#     200 if linestyle is None and marker is None:
#     201     linestyle = mpl.rcParams['lines.linestyle']
#
# ValueError: 'color' is not a valid format string (unrecognized character 'l')

# %%
qt.draw(color='red',save="h03.png",axes='on')

# %%
rg = Regle(pi/6, 0.1732050807566133)

# %%
rg.draw(save="desequilibre30_017.png",axes='on')

# %%
rg = Regle(pi/30,0.28554); rg.draw(color="yellow",save=True,axes='on')

# %%
q75 = Regle(pi/10,0.23776412907279743);q75.draw(save=True,axes='on')

# %%
qt = Regle(0.08726646259971647,0.2864739302928102)

# %%
tt = 0.08726646259971647

# %%
 Regle(0.08726646259971647,0.2988584094275236).densite
# Out:
# 0.8

# %%
Regle(0.08726646259971647,0.2988584094275236).draw(save=True,axes='on')

# %%
q = solution(radians(18)); q.draw(save=True,axes='on')

# %%
q = solution(radians(44)); q.draw(save=True,axes='on')

# %% [markdown]
# La plus grande densité compatible avec un équilibre symétrique d'inclinaison 45° est d = 23/32

# %%
for d in range (44,0,-2):
    q = solution(radians(d))
    q.draw(save=True, axes='on')
    time.sleep(1.5)

# %%
rg =Regle(0,0.20);rg.draw(color="red",save=True,axes='on')

# %%
1
# Out:
# 1

# %%
A=Point(0,1)
B=Point(1,2)
C=Point(2,5)

# %%
p=Polygone([A,B,C])

# %%
p.draw()

# %%
p.afficher()
# Out:
# Polygone : aire = 1.0, périmètre = 9.048627177541054

# %%
qt.draw(save=True)
